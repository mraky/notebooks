# %%
from  mjupyutils import show
dataset=[
    {
        "name":"set1",
        "data":[
                    [1214179200000,27.97],
                    [1214265600000,3.73],
                    [1214352000000,28.35],
                    [1214438400000,6.75],
                    [1214524800000,27.63],
                    [1214784000000,27.51],
        ]
    },
        {
        "name":"set2",
        "data":[
                    [1214179200000,40.97],
                    [1214265600000,11.73],
                    [1214352000000,23.35],
                    [1214438400000,2.75],
                    [1214524800000,8.63],
                    [1214784000000,3.51],
        ]
    }
    
]


show.chart(dataset)
# Out:
# <script>
# if(window['datatable'] === undefined){
#
#
# require({
#     paths: {
#  //       'hchart': "http://code.highcharts.com/highcharts",
#  //       'hchart-more': "http://code.highcharts.com/highcharts-more",
#
#         'hchart': "http://code.highcharts.com/stock/highstock",
#
#
#         'hchart-export': "http://code.highcharts.com/modules/exporting",
#         'jquery': "//cdnjs.cloudflare.com/ajax/libs/jquery/1.8.2/jquery.min"
#     }
# }, ['jquery', 'hchart','hchart-export'], function($, hc) {
#
#     window['datatable'] = " ";
#     console.log('starting to render datatable:');
# 	var event = document.createEvent("HTMLEvents");
# 	event.initEvent("load_datatable", true, false);
# 	window.dispatchEvent(event);
#     });
# }
# </script>
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8/>
#     <title>Animated </title>
#
#
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#
# ...
